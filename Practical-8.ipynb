# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sheet = pd.read_csv('train.csv.xls')

# %%
print(sheet)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
display(sheet)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sheet.shape
# Out:
# (891, 12)

# %%
sheet.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sheet.describe(include='object')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
sheet.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sheet['Age']= sheet['Age'].fillna(np.mean(sheet['Age']))

# %%
sheet['Cabin']=sheet['Cabin'].fillna(sheet['Cabin'].mode()[0])

# %%
sheet['Embarked']=sheet['Embarked'].fillna(sheet['Embarked'].mode()[0])

# %%
sheet.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
sns.countplot(x=sheet['Survived'])
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=sheet['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=sheet['Embarked'])
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
sns.countplot(x=sheet['Sex'])
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x=sheet['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=sheet['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare'>

# %%
sns.boxplot(x=sheet['Pclass'])
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %%
sns.boxplot(x=sheet['SibSp'])
# Out:
# <AxesSubplot:xlabel='SibSp'>

# %%
sns.catplot(x='Pclass', y= 'Age', data=sheet, kind='box')

# %%
sns.catplot(x='Pclass', y= 'Age', data=sheet, kind='box')

# %%
sns.catplot(x='Sex', y='Fare', data=sheet, kind='strip')

# %%
sns.catplot(x='Sex', y='Age', data=sheet, kind='strip')

# %%
sns.pairplot(sheet)

# %%
sns.scatterplot(x='Fare', y='Pclass', hue='Survived', data=sheet)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Pclass'>

# %%
sns.scatterplot(x='Survived', y='Fare', data=sheet)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.scatterplot(x='Survived', y='Fare', data=sheet)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.distplot(x=sheet['Age'])
# Out:
# C:\Users\Harshal Patil\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(x=sheet['Fare'])
# Out:
# C:\Users\Harshal Patil\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot(x="Survived", y="Fare", kind="scatter", data=sheet)

# %%
tc=sheet.corr()
sns.heatmap(tc, cmap="YlGnBu")
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
sns.catplot(x='Pclass', y='Fare', data=sheet, kind='bar')

# %%
sns.histplot(data=sheet, x='Fare', hue='Pclass', bins=30)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Count'>
